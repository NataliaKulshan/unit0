# %% [markdown]
# Проект 1. Кто хочет стать миллионером кинопроката?
# Задача: ответить на тестовые вопросы, применяя знания, полученные в этом юните. Использовать для этого файлы, приатаченные на сайте.
# Количество набранных в викторине баллов - 27.
#
# 1. В целом, довольна собой)
# 2. Не получилось использовать explode.
# 3. Все было полезно и интересно, но во время выполнения финального задания пришлось снова открывать все прорешенные задания из юнита.
# 4. Главный результат - что я смогла сделать финальное задание.
# 5. В этом модуле я больше смотрела вебинаров, это улучшило понимание, но и тема была полегче. Поэтому надо как-то все время повторять.
